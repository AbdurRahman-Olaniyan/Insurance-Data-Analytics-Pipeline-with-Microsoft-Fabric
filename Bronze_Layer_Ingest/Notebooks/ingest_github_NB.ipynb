# %%
#Ingest source data from github
# Out:
# StatementMeta(, bca816a7-c5b4-4533-99ff-37663d40b4fc, 3, Finished, Available, Finished)

# %%
import requests

OWNER = "AbdurRahman-Olaniyan"
REPO = "Insurance_data"
BRANCH = "main"
FOLDER_PATH = ""

BRONZE_DIR = "Files/bronze/github"
# Out:
# StatementMeta(, 1689c5ea-aac7-4e31-8427-64a17cb01387, 3, Finished, Available, Finished, False)

# %%
def get_csv_file_list():

    api_url = (
        f"https://api.github.com/repos/"
        f"{OWNER}/{REPO}/contents/{FOLDER_PATH}?ref={BRANCH}"
    )

    response = requests.get(api_url)
    response.raise_for_status()

    repo_items = response.json()

    csv_files = [
        item for item in repo_items
        if item["type"] == "file"
        and item["name"].lower().endswith(".csv")
    ]

    return csv_files
# Out:
# StatementMeta(, 1689c5ea-aac7-4e31-8427-64a17cb01387, 4, Finished, Available, Finished, False)

# %%
def copy_file_to_bronze(download_url, filename):

    print("Downloading:", filename)

    response = requests.get(download_url)
    response.raise_for_status()

    tmp_path = f"/tmp/{filename}"

    with open(tmp_path, "wb") as f:
        f.write(response.content)

    try:
        fs = notebookutils.fs
    except:
        fs = mssparkutils.fs

    fs.mkdirs(BRONZE_DIR)

    dest_path = f"{BRONZE_DIR}/{filename}"
    fs.cp(f"file:{tmp_path}", dest_path, True)

    print("Saved:", dest_path)
# Out:
# StatementMeta(, 1689c5ea-aac7-4e31-8427-64a17cb01387, 5, Finished, Available, Finished, False)

# %%
def run_github_bronze_ingestion():

    files = get_csv_file_list()

    print("CSV files found:")
    for f in files:
        print("-", f["name"])

    print("\nStarting copy...\n")

    for f in files:
        copy_file_to_bronze(
            download_url=f["download_url"],
            filename=f["name"]
        )

    print("\nBronze ingestion complete")
# Out:
# StatementMeta(, 1689c5ea-aac7-4e31-8427-64a17cb01387, 6, Finished, Available, Finished, False)

# %%
run_github_bronze_ingestion()
# Out:
# StatementMeta(, 1689c5ea-aac7-4e31-8427-64a17cb01387, 7, Finished, Available, Finished, True)
# CSV files found:
# - agent.csv
# - customer.csv
# - date.csv
# - product.csv
#
# Starting copy...
#
# Downloading: agent.csv
# Saved: Files/bronze/github/agent.csv
# Downloading: customer.csv
# Saved: Files/bronze/github/customer.csv
# Downloading: date.csv
# Saved: Files/bronze/github/date.csv
# Downloading: product.csv
# Saved: Files/bronze/github/product.csv
#
# Bronze ingestion complete
