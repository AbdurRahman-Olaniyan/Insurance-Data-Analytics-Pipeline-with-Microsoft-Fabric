# %%
from pyspark.sql.types import StructType, StructField, StringType
from pyspark.sql.functions import current_timestamp, input_file_name

BASE = "Files/bronze/"

def load_csv_as_string(path: str, schema: StructType):
    return (spark.read.format("csv")
            .option("header", "true")
            .schema(schema)
            .load(path)
            .withColumn("_ingest_ts", current_timestamp())
            .withColumn("_source_file", input_file_name())
            )
# Out:
# StatementMeta(, 980a9fdd-7f0f-4768-9fd3-d28098869d30, 7, Finished, Available, Finished, False)

# %%
incident_schema = StructType([
    StructField("IncidentID", StringType(), True),
    StructField("ClaimID", StringType(), True),
    StructField("IncidentDate", StringType(), True),
    StructField("IncidentType", StringType(), True),
    StructField("Severity", StringType(), True),
    StructField("Description", StringType(), True),
])

renewal_schema = StructType([
    StructField("RenewalID", StringType(), True),
    StructField("PolicyNo", StringType(), True),
    StructField("RenewalDate", StringType(), True),
    StructField("Amount", StringType(), True),
    StructField("PaymentMethod", StringType(), True),
])

agent_schema = StructType([
    StructField("AgentID", StringType(), True),
    StructField("AgentName", StringType(), True),
    StructField("Region", StringType(), True),
    StructField("HireDate", StringType(), True),
    StructField("PerformanceRating", StringType(), True),
])

customer_schema = StructType([
    StructField("CustomerID", StringType(), True),
    StructField("FullName", StringType(), True),
    StructField("Gender", StringType(), True),
    StructField("DOB", StringType(), True),
    StructField("City", StringType(), True),
    StructField("Country", StringType(), True),
    StructField("Email", StringType(), True),
    StructField("Phone", StringType(), True),
    StructField("JoinDate", StringType(), True),
])

date_schema = StructType([
    StructField("DateKey", StringType(), True),
    StructField("FullDate", StringType(), True),
    StructField("Year", StringType(), True),
    StructField("Quarter", StringType(), True),
    StructField("Month", StringType(), True),
    StructField("MonthName", StringType(), True),
    StructField("Day", StringType(), True),
    StructField("DayOfWeek", StringType(), True),
])

product_schema = StructType([
    StructField("ProductID", StringType(), True),
    StructField("ProductName", StringType(), True),
    StructField("Category", StringType(), True),
    StructField("Premium", StringType(), True),
    StructField("CoverageType", StringType(), True),
    StructField("DurationMonths", StringType(), True),
])
# Out:
# StatementMeta(, 980a9fdd-7f0f-4768-9fd3-d28098869d30, 8, Finished, Available, Finished, False)

# %%
# incident
df = load_csv_as_string(BASE + "azureblob/incident.csv", incident_schema)
df.write.format("delta").mode("overwrite").saveAsTable("stg_incident")
# Out:
# StatementMeta(, 980a9fdd-7f0f-4768-9fd3-d28098869d30, 9, Finished, Available, Finished, False)

# %%
# renewal
df = load_csv_as_string(BASE + "azureblob/renewal.csv", renewal_schema)
df.write.format("delta").mode("overwrite").saveAsTable("stg_renewal")
# Out:
# StatementMeta(, 980a9fdd-7f0f-4768-9fd3-d28098869d30, 10, Finished, Available, Finished, False)

# %%
# agent
df = load_csv_as_string(BASE + "github/agent.csv", agent_schema)
df.write.format("delta").mode("overwrite").saveAsTable("stg_agent")
# Out:
# StatementMeta(, 980a9fdd-7f0f-4768-9fd3-d28098869d30, 11, Finished, Available, Finished, False)

# %%
# customer
df =load_csv_as_string(BASE + "github/customer.csv", customer_schema)
df.write.format("delta").mode("overwrite").saveAsTable("stg_customer")
# Out:
# StatementMeta(, 980a9fdd-7f0f-4768-9fd3-d28098869d30, 12, Finished, Available, Finished, False)

# %%
# date
df = load_csv_as_string(BASE + "github/date.csv", date_schema)
df.write.format("delta").mode("overwrite").saveAsTable("stg_date")
# Out:
# StatementMeta(, 980a9fdd-7f0f-4768-9fd3-d28098869d30, 13, Finished, Available, Finished, False)

# %%
# product
df = load_csv_as_string(BASE + "github/product.csv", product_schema)
df.write.format("delta").mode("overwrite").saveAsTable("stg_product")
# Out:
# StatementMeta(, 980a9fdd-7f0f-4768-9fd3-d28098869d30, 14, Finished, Available, Finished, False)

# %%
tables = ["stg_incident", "stg_renewal", "stg_agent", "stg_customer", "stg_date", "stg_product"]

for t in tables:
    print("\n" + "="*40)
    print("TABLE:", t)
    print("ROWS :", spark.table(t).count())
    spark.table(t).printSchema()
    spark.table(t).show(5, truncate=False)
# Out:
# StatementMeta(, 980a9fdd-7f0f-4768-9fd3-d28098869d30, 18, Finished, Available, Finished, False)
# ========================================
# TABLE: stg_incident
# ROWS : 11478
# root
#  |-- IncidentID: string (nullable = true)
#  |-- ClaimID: string (nullable = true)
#  |-- IncidentDate: string (nullable = true)
#  |-- IncidentType: string (nullable = true)
#  |-- Severity: string (nullable = true)
#  |-- Description: string (nullable = true)
#  |-- _ingest_ts: timestamp (nullable = true)
#  |-- _source_file: string (nullable = true)
#
# +----------+--------+------------+----------------+--------+---------------------------+--------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |IncidentID|ClaimID |IncidentDate|IncidentType    |Severity|Description                |_ingest_ts                |_source_file                                                                                                                                                                               |
# +----------+--------+------------+----------------+--------+---------------------------+--------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |INC00001  |CLM00001|27/04/2023  |Electrical Surge|Medium  |Smoke damage to living room|2026-02-12 14:18:08.726883|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/azureblob/incident.csv?version=1770842594295?flength=846115|
# |INC00002  |CLM00001|16/04/2023  |Electrical Surge|Low     |Minor scratch              |2026-02-12 14:18:08.726883|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/azureblob/incident.csv?version=1770842594295?flength=846115|
# |INC00003  |CLM00002|24/05/2025  |Fire Outbreak   |Low     |Water damage to electronics|2026-02-12 14:18:08.726883|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/azureblob/incident.csv?version=1770842594295?flength=846115|
# |INC00004  |CLM00002|26/06/2025  |Flood Damage    |High    |Smoke damage to living room|2026-02-12 14:18:08.726883|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/azureblob/incident.csv?version=1770842594295?flength=846115|
# |INC00005  |CLM00003|08/08/2021  |Theft           |Medium  |Smoke damage to living room|2026-02-12 14:18:08.726883|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/azureblob/incident.csv?version=1770842594295?flength=846115|
# +----------+--------+------------+----------------+--------+---------------------------+--------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows
#
#
# ========================================
# TABLE: stg_renewal
# ROWS : 21781
# root
#  |-- RenewalID: string (nullable = true)
#  |-- PolicyNo: string (nullable = true)
#  |-- RenewalDate: string (nullable = true)
#  |-- Amount: string (nullable = true)
#  |-- PaymentMethod: string (nullable = true)
#  |-- _ingest_ts: timestamp (nullable = true)
#  |-- _source_file: string (nullable = true)
#
# +---------+--------+-----------+-------+-------------+-------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |RenewalID|PolicyNo|RenewalDate|Amount |PaymentMethod|_ingest_ts               |_source_file                                                                                                                                                                              |
# +---------+--------+-----------+-------+-------------+-------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |R00001   |POL00001|11/12/2021 |90000  |Cash         |2026-02-12 14:18:43.36861|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/azureblob/renewal.csv?version=1770842594293?flength=891547|
# |R00002   |POL00004|28/03/2026 |180000 |Card         |2026-02-12 14:18:43.36861|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/azureblob/renewal.csv?version=1770842594293?flength=891547|
# |R00003   |POL00005|08/03/2021 |₦60,000|USSD         |2026-02-12 14:18:43.36861|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/azureblob/renewal.csv?version=1770842594293?flength=891547|
# |R00004   |POL00006|08/11/2022 |120000 |Cash         |2026-02-12 14:18:43.36861|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/azureblob/renewal.csv?version=1770842594293?flength=891547|
# |R00005   |POL00010|02/03/2022 |180000 |Card         |2026-02-12 14:18:43.36861|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/azureblob/renewal.csv?version=1770842594293?flength=891547|
# +---------+--------+-----------+-------+-------------+-------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows
#
#
# ========================================
# TABLE: stg_agent
# ROWS : 120
# root
#  |-- AgentID: string (nullable = true)
#  |-- AgentName: string (nullable = true)
#  |-- Region: string (nullable = true)
#  |-- HireDate: string (nullable = true)
#  |-- PerformanceRating: string (nullable = true)
#  |-- _ingest_ts: timestamp (nullable = true)
#  |-- _source_file: string (nullable = true)
#
# +-------+---------------+-------+----------+-----------------+--------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |AgentID|AgentName      |Region |HireDate  |PerformanceRating|_ingest_ts                |_source_file                                                                                                                                                                       |
# +-------+---------------+-------+----------+-----------------+--------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |AGT001 |Uche Nwankwo   |Kano   |18/05/2023|3.9              |2026-02-12 14:19:14.003672|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/github/agent.csv?version=1770827301621?flength=5107|
# |AGT002 |Tunde Ojo      |Plateau|05/03/2024|3.3              |2026-02-12 14:19:14.003672|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/github/agent.csv?version=1770827301621?flength=5107|
# |AGT003 |Olamide Johnson|Plateau|08/04/2025|4.7              |2026-02-12 14:19:14.003672|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/github/agent.csv?version=1770827301621?flength=5107|
# |AGT004 |Ibrahim Okafor |Lagos  |30/05/2015|2.9              |2026-02-12 14:19:14.003672|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/github/agent.csv?version=1770827301621?flength=5107|
# |AGT005 |Tunde Okafor   |Edo    |16/02/2024|3.0              |2026-02-12 14:19:14.003672|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/github/agent.csv?version=1770827301621?flength=5107|
# +-------+---------------+-------+----------+-----------------+--------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows
#
#
# ========================================
# TABLE: stg_customer
# ROWS : 3000
# root
#  |-- CustomerID: string (nullable = true)
#  |-- FullName: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- DOB: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- Email: string (nullable = true)
#  |-- Phone: string (nullable = true)
#  |-- JoinDate: string (nullable = true)
#  |-- _ingest_ts: timestamp (nullable = true)
#  |-- _source_file: string (nullable = true)
#
# +----------+------------------+------+----------+-------------+-------+----------------------------+-----------+----------+--------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |CustomerID|FullName          |Gender|DOB       |City         |Country|Email                       |Phone      |JoinDate  |_ingest_ts                |_source_file                                                                                                                                                                            |
# +----------+------------------+------+----------+-------------+-------+----------------------------+-----------+----------+--------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |CUST0001  |Emeka Sani        |Male  |05/01/1970|Aba          |Nigeria|emeka.sani@yahoo.com        |09119600133|01/10/2019|2026-02-12 14:19:34.222556|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/github/customer.csv?version=1770827302143?flength=310268|
# |CUST0002  |David Afolayan    |Male  |20/11/1969|Abeokuta     |Nigeria|david.afolayan@hotmail.com  |07026542351|15/09/2021|2026-02-12 14:19:34.222556|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/github/customer.csv?version=1770827302143?flength=310268|
# |CUST0003  |Ahmed Bello       |Male  |30/01/1987|Owerri       |Nigeria|ahmed.bello@outlook.com     |09116184959|09/11/2020|2026-02-12 14:19:34.222556|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/github/customer.csv?version=1770827302143?flength=310268|
# |CUST0004  |Sulaiman Musa     |Male  |11/06/1980|Abuja        |Nigeria|sulaiman.musa@outlook.com   |07064752553|01/06/2024|2026-02-12 14:19:34.222556|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/github/customer.csv?version=1770827302143?flength=310268|
# |CUST0005  |Oluwaseun Olatunji|Female|09/05/1975|Port Harcourt|Nigeria|oluwaseun.olatunji@yahoo.com|09135030564|01/11/2023|2026-02-12 14:19:34.222556|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/github/customer.csv?version=1770827302143?flength=310268|
# +----------+------------------+------+----------+-------------+-------+----------------------------+-----------+----------+--------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows
#
#
# ========================================
# TABLE: stg_date
# ROWS : 2192
# root
#  |-- DateKey: string (nullable = true)
#  |-- FullDate: string (nullable = true)
#  |-- Year: string (nullable = true)
#  |-- Quarter: string (nullable = true)
#  |-- Month: string (nullable = true)
#  |-- MonthName: string (nullable = true)
#  |-- Day: string (nullable = true)
#  |-- DayOfWeek: string (nullable = true)
#  |-- _ingest_ts: timestamp (nullable = true)
#  |-- _source_file: string (nullable = true)
#
# +--------+----------+----+-------+-----+---------+---+---------+--------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |DateKey |FullDate  |Year|Quarter|Month|MonthName|Day|DayOfWeek|_ingest_ts                |_source_file                                                                                                                                                                        |
# +--------+----------+----+-------+-----+---------+---+---------+--------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |20200101|01/01/2020|2020|Q1     |1    |January  |1  |Wednesday|2026-02-12 14:19:50.426503|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/github/date.csv?version=1770827302578?flength=108016|
# |20200102|02/01/2020|2020|Q1     |1    |January  |2  |Thursday |2026-02-12 14:19:50.426503|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/github/date.csv?version=1770827302578?flength=108016|
# |20200103|03/01/2020|2020|Q1     |1    |January  |3  |Friday   |2026-02-12 14:19:50.426503|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/github/date.csv?version=1770827302578?flength=108016|
# |20200104|04/01/2020|2020|Q1     |1    |January  |4  |Saturday |2026-02-12 14:19:50.426503|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/github/date.csv?version=1770827302578?flength=108016|
# |20200105|05/01/2020|2020|Q1     |1    |January  |5  |Sunday   |2026-02-12 14:19:50.426503|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/github/date.csv?version=1770827302578?flength=108016|
# +--------+----------+----+-------+-----+---------+---+---------+--------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows
#
#
# ========================================
# TABLE: stg_product
# ROWS : 20
# root
#  |-- ProductID: string (nullable = true)
#  |-- ProductName: string (nullable = true)
#  |-- Category: string (nullable = true)
#  |-- Premium: string (nullable = true)
#  |-- CoverageType: string (nullable = true)
#  |-- DurationMonths: string (nullable = true)
#  |-- _ingest_ts: timestamp (nullable = true)
#  |-- _source_file: string (nullable = true)
#
# +---------+--------------------+--------+-------+-------------+--------------+--------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |ProductID|ProductName         |Category|Premium|CoverageType |DurationMonths|_ingest_ts                |_source_file                                                                                                                                                                         |
# +---------+--------------------+--------+-------+-------------+--------------+--------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |PROD001  |Auto Shield Basic   |Vehicle |45000  |Third Party  |12            |2026-02-12 14:20:06.658344|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/github/product.csv?version=1770827303011?flength=1120|
# |PROD002  |Auto Shield Plus    |Vehicle |85000  |Comprehensive|12            |2026-02-12 14:20:06.658344|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/github/product.csv?version=1770827303011?flength=1120|
# |PROD003  |Auto Shield Fleet   |Vehicle |150000 |Fleet        |12            |2026-02-12 14:20:06.658344|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/github/product.csv?version=1770827303011?flength=1120|
# |PROD004  |Health Secure Basic |Health  |90000  |Individual   |12            |2026-02-12 14:20:06.658344|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/github/product.csv?version=1770827303011?flength=1120|
# |PROD005  |Health Secure Family|Health  |180000 |Family       |12            |2026-02-12 14:20:06.658344|abfss://78f80563-5b6e-48d0-a7fb-57bffbebc707@onelake.dfs.fabric.microsoft.com/d394d85d-852a-4796-9592-88557c44e14d/Files/bronze/github/product.csv?version=1770827303011?flength=1120|
# +---------+--------------------+--------+-------+-------------+--------------+--------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows
